# %% [markdown]
# 41. Bool False

# %%
assert bool(0) == False
assert bool("") == False
assert bool("0") == True
assert bool(" ") == True
assert bool() == False
assert bool(  ) == False
assert bool('hello') == True
assert bool(111) == True
assert bool([]) == False
assert bool([1]) == True
assert bool({}) == False
assert bool({ }) == False
assert bool([0]) == True
assert bool([ ]) == False
assert bool(-1) == True

# %% [markdown]
# 42. Krótki obliczanie - short-circuits (and/or)
#
# - and zwraca pierwszą false lub ostatnią true
# - or zwraca pierwszą true lub ostatnią false

# %%
assert (0 or 11) == 11
assert (0 and 11) == 0
assert ("" or 0) == 0
assert (55 or 44) == 55
assert (5 or 0) == 5
assert (0 or 5) == 5
assert (7 and 3) == 3
assert (3 and 7) == 7
assert (0 and 7) == 0
assert (7 and 0) == 0
assert ("" or "abc") == "abc"
assert ("abc" or "") == "abc"
assert ("" and "abc") == ""
assert ("abc" and "") == ""
assert (None or 9) == 9
assert (9 or None) == 9
assert (None and 9) == None
assert (9 and None) == None
assert (True or False) == True
assert (False or True) == True
assert (True and False) == False
assert (False and True) == False
assert ([] or [1]) == [1]
assert ([1] or []) == [1]
assert ([] and [1]) == []
assert ([1] and []) == []
assert (0 or False) == False
assert (False or 0) == 0
assert (0 and False) == 0
assert (False and 0) == False
assert (5 or 10) == 5
assert (10 and 5) == 5
assert ("" or []) == []
assert (None or "OK") == "OK"

# %% [markdown]
# 43. if elif else
#
# Napisz kod, który na podstawie liczby punktów (points) przypisze ocenę (grade) według poniższych zasad:
#
# mniej niż 50 punktów → "niedostateczny"
#
# od 50 do 69 → "dostateczny"
#
# od 70 do 84 → "dobry"
#
# 85 lub więcej → "bardzo dobry"

# %%
points = 44
if (points < 50) and (points > 0):
    grade = "niedostateczny"
    print (grade)
elif (points < 69) and (points >= 50):
    grade = "dostateczny"
    print (grade)
elif (points < 84) and (points >= 70):
    grade = "dobry"
    print (grade)
elif (points <= 100) and (points >= 85):
    grade = "bardzo dobry"
    print (grade)
elif points != range(100):
    grade = "bracie to nie stopnie fahrenhainta"
    print (grade)

points = 55
if (points < 50) and (points > 0):
    grade = "niedostateczny"
    print (grade)
elif (points < 69) and (points >= 50):
    grade = "dostateczny"
    print (grade)
elif (points < 84) and (points >= 70):
    grade = "dobry"
    print (grade)
elif (points <= 100) and (points >= 85):
    grade = "bardzo dobry"
    print (grade)
elif points != range(100):
    grade = "bracie to nie stopnie fahrenhainta"
    print (grade)

points = 77
if (points < 50) and (points > 0):
    grade = "niedostateczny"
    print (grade)
elif (points < 69) and (points >= 50):
    grade = "dostateczny"
    print (grade)
elif (points < 84) and (points >= 70):
    grade = "dobry"
    print (grade)
elif (points <= 100) and (points >= 85):
    grade = "bardzo dobry"
    print (grade)
elif points != range(100):
    grade = "bracie to nie stopnie fahrenhainta"
    print (grade)

points = 99
if (points < 50) and (points > 0):
    grade = "niedostateczny"
    print (grade)
elif (points < 69) and (points >= 50):
    grade = "dostateczny"
    print (grade)
elif (points < 84) and (points >= 70):
    grade = "dobry"
    print (grade)
elif (points <= 100) and (points >= 85):
    grade = "bardzo dobry"
    print (grade)
elif points != range(100):
    grade = "bracie to nie stopnie fahrenhainta"
    print (grade)

points = 105
if (points < 50) and (points > 0):
    grade = "niedostateczny"
    print (grade)
elif (points < 69) and (points >= 50):
    grade = "dostateczny"
    print (grade)
elif (points < 84) and (points >= 70):
    grade = "dobry"
    print (grade)
elif (points <= 100) and (points >= 85):
    grade = "bardzo dobry"
    print (grade)
elif points != range(100):
    grade = "bracie to nie stopnie fahrenhainta"
    print (grade)

points = 101
if (points < 50) and (points > 0):
    grade = "niedostateczny"
    print (grade)
elif (points < 69) and (points >= 50):
    grade = "dostateczny"
    print (grade)
elif (points < 84) and (points >= 70):
    grade = "dobry"
    print (grade)
elif (points <= 100) and (points >= 85):
    grade = "bardzo dobry"
    print (grade)
elif points != range(100):
    grade = "bracie to nie stopnie fahrenhainta"
    print (grade)

points = 0
grade = (
    "niedostateczny" if 0 <= points < 50 else
    "dostateczny" if 50 <= points < 69 else
    "dobry" if 70 <= points < 84 else
    "bardzo dobry" if 85 <= points <= 100 else
    "bracie to nie stopnie fahrenhainta"
)
print(grade)
# Out:
# niedostateczny
# dostateczny
# dobry
# bardzo dobry
# bracie to nie stopnie fahrenhainta
# bracie to nie stopnie fahrenhainta
# niedostateczny

# %% [markdown]
# 44. operatorzy
#
# 🧩 Zadanie 1
# Napisz program, który sprawdza, czy dana osoba jest nastolatkiem, czyli ma wiek od 11 do 19 lat włącznie.
#
# 🧩 Zadanie 2
# Sprawdź, czy podana liczba jest parzysta i jednocześnie mieści się w zakresie od 0 do 100 włącznie.
#
# 🧩 Zadanie 3
# Sprawdź, czy długość podanego hasła mieści się w dopuszczalnym zakresie — od 8 do 20 znaków włącznie.
#
# 🧩 Zadanie 4
# Sprawdź, czy temperatura jest poza komfortowym zakresem, czyli poniżej 0°C lub powyżej 30°C.
#
# 🧩 Zadanie 5
# Sprawdź, czy punkt na osi liczbowej znajduje się po lewej stronie zera, czyli ma wartość ujemną.

# %%
x = 14
assert (11 <= x <= 19) is True
x = 55
assert ((x % 2 == 0) and (0 <= x <= 100)) is False
hasło = "FranciszkuNieUstawaj"
assert (6 <= len(hasło) <= 20) is True
temp = 15
assert (30 <= temp <= 0) is False
punkt = -3.33333333344343444434444444444444
assert (punkt < 0) is True

# %% [markdown]
# Dodatkowo użyteczne w warunkach: > * **przynależność**: in / not in → if ext in {"jpg", "png"}: > * **tożsamość**: is / is not dla None → if value is None:

# %% [markdown]
# 45. is none oraz in it

# %% [markdown]
# 🧩 Zadanie 1 — rozszerzenie pliku
#
# Napisz program, który sprawdza, czy rozszerzenie pliku należy do zbioru grafik ("jpg", "png", "gif").
# Jeśli tak — przypisz zmiennej file_type = "obraz", w przeciwnym razie "inne".
#
# 🧩 Zadanie 2 — zakazane słowa
#
# Sprawdź, czy w podanym zdaniu występuje któreś z niedozwolonych słów ("brzydkie", "zakazane", "tajne").
# Jeśli tak — ustaw allowed = False, w przeciwnym razie True.
#
# 🧩 Zadanie 3 — brak wartości
#
# Sprawdź, czy zmienna data ma wartość None.
# Jeśli tak — przypisz "brak danych", jeśli nie — "dane wczytane".
#
# 🧩 Zadanie 4 — lista użytkowników
#
# Sprawdź, czy użytkownik username znajduje się w liście ["admin", "moderator", "tester"].
# Jeśli tak — przypisz "dostęp przyznany", w przeciwnym razie "odmowa dostępu".
#
# 🧩 Zadanie 5 — wartość pusta
#
# Sprawdź, czy zmienna value nie ma żadnej wartości (czyli is None) lub jest pustym napisem ("").
# Jeśli tak — przypisz "pusto", w przeciwnym razie "zawartość istnieje".
#
# 🧩 Zadanie 6 — członkostwo w zestawie
#
# Utwórz zbiór dozwolone_kody = {"A1", "B2", "C3"} i sprawdź, czy kod user_code się w nim znajduje.
# Zmienna valid ma przyjąć wartość True lub False.
#
# 🧩 Zadanie 7 — brak obiektu
#
# Sprawdź, czy zmienna user_profile nie została jeszcze utworzona (czyli jest None).
# Jeśli tak — przypisz "brak profilu", jeśli istnieje — "profil aktywny"

# %%
rozszerzenie = "jpg"
rozszerzenia = {"jpg", "png", "gif"}
if rozszerzenie in rozszerzenia:
    file_type = "obraz"
    allowed = False
else:
    allowed = True

assert (allowed == False) is True

zdanie = "kocham, miłość, piękno, siła"
if "miłość" in zdanie:
    allowed = True
else:
    allowed = False

assert (((allowed == True) is True) is True) is True

date = None

if date is None:
    date_type = "brak danych"
else:
    date_type = "no są dane"

assert (date_type == ("brak danych")) is True

lista = ["admin", "moderator", "tester"]
username = "uszatymaurycy"

if username in lista:
    access = "dostęp przyznany"
else:
    access = "brak dostępu"

assert access == "brak dostępu"

dozwolone_kody = {"A1", "B2", "C3"}
user_code = "C3"

if user_code in dozwolone_kody:
    tak = "tak"
else:
    tak = "nie"

assert tak == "tak"

user_profile = "Franciszek"

if user_profile is None:
    status = "nie utworzono"
else:
    status = "utworzono"

assert status == "utworzono"

# %% [markdown]
# 46. łączenie warunków logicznych

# %%
age, has_ticket = 13, "yes"
can_enter = (age >= 18) and (has_ticket == "yes")

assert can_enter is False

is_student, age = "tak", 21
get_discount = (is_student == "tak") and (age >= 16)

assert get_discount is True

password_length, has_number = 20, "no"
good_password = ((password_length >= 6) and (has_number == "yes")) or (password_length >= 12)

assert good_password is True

temp, alarm_on = 33, "off"
safe = (0 <= temp <= 40) and ((alarm_on == "off") or (temp < 30))
safe
# Out:
# True

# %% [markdown]
# 47. warunki zagnieżdżone, dzielenie z kontrolą błędów i sprawdzanie zakresów

# %%
done = 111
total = 77

if total == 0:
    result = None
else:
    percent = done / total
    if 0 < percent < 1:
        percent is None
    else:
        print(percent)

fuel_used = 14
distance = 69


if distance <= 0:
    consumption = None
else:
    consumption = fuel_used / distance
    if 1 < consumption < 0:
        consumption = None
    else:
        print(consumption)

num, den = 33, 69

if den == 0:
    result is None
else:
    result = num / den
    if 1 < result < -1:
        result is None
print(result)

tasks_done, tasks_total = 17, 17
if tasks_total < 0:
    result is None
else:
    result = tasks_done / tasks_total
    if 0 > result > 1:
        result is None
print(result)

score, max_score = 100, 100
if max_score == 0:
    result is None
else:
    result = max_score / score
    if 0 > result > 1:
        result is None
print(result)
# Out:
# 1.4415584415584415
# 0.2028985507246377
# 0.4782608695652174
# 1.0
# 1.0

# %% [markdown]
# 48. Wyrażenie warunkowe

# %%
score = 100

if score >= 50:
    pass
else:
    status = "niezaliczony"

wynik = "zaliczony" if score >= 50 else status == "niezaliczony"
print(wynik)

temp = -1
temp_is_good = "plus" if temp > 10 else print("bad")

n = 44
czy_parzysta = "even" if not (n % 2) else "odd"
print(czy_parzysta)
# Out:
# zaliczony
# bad
# even

# %% [markdown]
# 49. pętle for

# %%
nums = [5, 8, 3, 10, 2]
x = 0
for n in nums:
    if n % 2 == 0:
        x += n
assert x == 20

text = "PYTHON"
lista = []
for x in text:
    lista.append(x.lower())
assert lista == ["p", "y", "t", "h", "o", "n"]

words = ["Ala", "ma", "kota"]
długość = []
for x in words:
    długość.append(len(x))
assert długość == [3, 2, 4]

from io import StringIO
fake_file = StringIO("Ala\n\nma\n\nkota\n")
empty = 0
for x in fake_file:
    x = x.rstrip("\n")
    if x == "":
        empty += 1
assert empty == 2

# rstrip(chars) — usuwa podane znaki z końca (np. \n, spacje).
# 👉 x.rstrip("\n") usuwa wszystkie znaki nowej linii z prawej strony napisu.

# startswith(prefix) — sprawdza, czy napis zaczyna się od podanego prefiksu.
# 👉 "error: foo".startswith("error:") zwraca True.

from io import StringIO
fake_file = StringIO("ok\nwarning: low\nerror: fail\nwarning: timeout\nok\n")
# ile lini zaczyna się od warning?
count = 0
for x in fake_file:
    x = x.rstrip("\n") # na początku daliśmy x.rstrip() -> też działało, ale nie było poprawne
    if x.startswith("warning:"):
        count += 1
assert count == 2

names = ["Ania", "Bartek", "Celina"]
# Zbuduj listę pairs, w której każdy element to krotka (numer, imię) — numer zaczyna się od 1.
pairs = []
for numer, imię in enumerate(names, start = 1):
    pairs.append((numer, imię))
assert pairs == [(1, "Ania"), (2, "Bartek"), (3, "Celina")]

words = ["pies", "kot", "papuga"]
# Utwórz listę info, gdzie każda krotka zawiera (numer, długość słowa).
info = []
for (numer,  długość) in enumerate(words, start = 1):
    w = len(długość)
    info.append((numer, w))
assert info == [(1, 4), (2, 3), (3, 6)]

names = ["Asia", "Bartek", "Celina"]
ages = [20, 25, 30]
# Połącz je w listę par (imię, wiek) z użyciem zip(..., strict=True).

połączone = list(zip(names, ages, strict = True))
print(połączone)

animals = ["pies", "kot"]
sounds = ["hau", "miau", "ćwir"]

łącznie = list(zip(animals, sounds))
print(łącznie)

rades = {"Ala": 5, "Bartek": 3, "Celina": 4}
# Stwórz listę names, która zawiera tylko imiona uczniów. (czyli klucze)
# Stwórz listę pairs, która zawiera krotki (imię, ocena).

names = [k for k in rades]
assert "Ala" in names
pairs = ((k, v) for k, v in rades.items())
assert ("Bartek", 3) in pairs
# Out:
# [('Asia', 20), ('Bartek', 25), ('Celina', 30)]
# [('pies', 'hau'), ('kot', 'miau')]

# %% [markdown]
# 50. pętle while

# %%
n = 6
acc = 6
while n > 0: # dopóki
    acc *= n
    n -= 1
assert acc == 4320

n = 10
acc = 0
while n > 0:
    acc += n
    n -= 1
assert acc == 55

n = 10
acc = 0
while n > 0:
    acc += n
    n += 1 # nie kończąca się pętla, while > 0 a zawsze będzie > 0
    break

data = [3, 8, 11, 4]
found_even = None
i = 0
while True:
    x = data[i]
    i += 1
    if x % 2 == 0:
        found_even = x
        break
    if i >= len(data):
        break # należy próbować zawsze uniknąć break ze względu na instotę kodu
assert found_even == 8

# program, który znajduje pierwszą liczbę ujemną w tym zbiorze
numbers = [4, 7, 12, -3, 9]
pierwsza_ujemna = None
i = 0
while True:
    x = numbers[i]
    i += 1
    if x < 0:
        pierwsza_ujemna = x
        break
assert pierwsza_ujemna == -3

# znajdź pierwszą podzielną przez 7
data = [5, 10, 15, 20, 25, 30, 77]
i = 0
pierwsza_podzielna_przez_7 = None

while True:
    x = data[i]
    i += 1
    if x % 7 == 0:
        pierwsza_podzielna_przez_7 = x
        break
    if i >= len(data):
        break
assert pierwsza_podzielna_przez_7 == 77

# %% [markdown]
# 51 sterowanie przebiegiem - continue i pass

# %%
# filtrowanie nieparzystych

nums = [3, 8, 11, 4, 6, 9]
clean = []

for x in nums:
    if x % 2 > 0:
        continue   # zamiast dodawać do listy parzyste to dodajemy przeciwieństwo
    clean.append(x)
assert clean == [8, 4, 6]

values = [5, -2, 7, -9, 4, 0, -3, 8]
bez_ujemnych = []

for x in values:
    if x < 0:
        continue
    bez_ujemnych.append(x)
assert bez_ujemnych == [5, 7, 4, 0, 8]

for y in nums:
    pass

# %% [markdown]
# 52 sterowanie przebiegiem - for i else

# %%
n = 2
if n < 2:
    is_prime = False
else:
    for d in range(2, int(n**0.5) + 1):
        if n % d == 0:
            is_prime = False
            break
    else:
        is_prime = True
assert is_prime is True

lista = [3, 8, 4, -1, 2]
ujemna = []
for x in lista:
    if x < 0:
        ujemna.append(x)
        print("znaleziono ujemną")
        break
else:
    print("znalezono dodatnią")

napis = "harceż" # spoko wiem
for x in napis:
    if x == "z":
        print ("Znaleziono literę Z")
        break
else:
    print ("nie ma Z")
# Out:
# znaleziono ujemną
# nie ma Z

# %% [markdown]
# 53 sterowanie przebiegiem - while ... else, ale zanim to to iter oraz next

# %%
lista = [11, 22, 33]
it_obiekt = iter(lista) # dzięki temu it_obiekt to obiekt pamiętający gdzie jesteśmy w liście, cokolwiek to znaczy
print(next(it_obiekt)) # oto funkcja zwracająca kolejny element iteratora - czyli it_obiektu
# mamy trzy elemntu, więc zobaczmy co się stanie, gdy ziterujemy to łącznie 4 razy
print(next(it_obiekt))
print(next(it_obiekt))
try:
    print(next(it_obiekt))
except: 
    StopIteration

# np.
    for x in lista:
        print (x) # mamy to samo, python robi to samo pod spodem

pin = 1234
próby = 3
lista_prób = [1111, 2222, 1234]
it = iter(lista_prób)

while próby > 0:
    próby -= 1
    if next(it) == pin:
        print("prawidłowy pin")
        break
    else:
        print("nieprawidłowy pin")
else:
    print("wyczerpano limit prób")


# teraz zrób program szukający hasła w pliku
passwords = ["123", "admin", "ziomek", "root"]
real_password = "admin"
próby = 3
it_haslo = iter(passwords)

while próby > 0:
    próby -= 1
    if real_password == next(it_haslo):
        print("dobre hasło bracie")
        break
    else:
        print("brak hasła na liście")
else:
    print("wyczerpano limit prób")
# Out:
# 11
# 22
# 33
# 11
# 22
# 33
# nieprawidłowy pin
# nieprawidłowy pin
# prawidłowy pin
# brak hasła na liście
# dobre hasło bracie

# %% [markdown]
# 54. szybka gierka na sterowanie przebiegiem z break, while, if, else

# %%
pin = 1234
próby = 3

while próby > 0:
        próby -= 1
        wpis = int(input("Podaj Pin:"))
        if wpis == pin:
            print("prawidłowy pin")
            break
        else:
            print ("nieprawidłowy pin")
else:
   print("wyczerpano limit prób")

lista_prób = [1111, 2222, 1234]
iterowany_obiekt = iter(lista_prób)
# Out:
# nieprawidłowy pin
# nieprawidłowy pin
# prawidłowy pin

# %% [markdown]
# 55. comprehension z listami i dict quick

# %%
a = ["pies", "kot", "żyrafa", "lew"]
a_len = [len(x) for x in a]
print(a_len)

lista = range(1, 20)
nowa_lista = [x*x*x for x in lista if x % 3 == 0]
print(nowa_lista)

words = range(1,5)
new_words = {w: w*w for w in words}
print(new_words)
print(words)
print(list(words))

# range(x,y) nie zadziała sam z siebie. zadziała wywołany lub dodatkowo zlistowany

imiona = ["Anna", "Bartek", "Adam", "Beata"]
new_imiona = {litera: [i for i in imiona if i.startswith(litera)] for litera in {i[0] for i in imiona}}
print (new_imiona) # mega dziwne, nie zrobiłbym sam
# Out:
# [4, 3, 6, 3]
# [27, 216, 729, 1728, 3375, 5832]
# {1: 1, 2: 4, 3: 9, 4: 16}
# range(1, 5)
# [1, 2, 3, 4]
# {'B': ['Bartek', 'Beata'], 'A': ['Anna', 'Adam']}

# %% [markdown]
# 56. set comprehesion

# %%
a = [" Ala ", "ALA", "ma ", "kota"]
b = {x.strip().lower() for x in a}
print(b)

d = ["Ala", "ma", "kota", "Ala"]
c = {x for x in d if x.startswith("A")}
print(c)

abc = ["pies", "koty", "tygrys"]
fed = sum(len(x) for x in abc if "y" in x)
print(fed)

ab = ["Ala", "ma", "kota"]
cd = sum((x.lower().count("a")) for x in ab if "a" in x)
print(cd)

# PERFEKCYJNIE WSZYSTKO SAM ESSSSAAAAAA
# Out:
# {'ma', 'ala', 'kota'}
# {'Ala'}
# 10
# 4

# %% [markdown]
# 57. mapowanie i filtrowanie w jednym - powtórka

# %%
words = ["  kot", "PIES ", "", "lew", " "]
new_words = [x.strip().casefold() for x in words if x.strip()]
print(new_words)

raw = ["  anna ", "BARTEK", " ", "adam", "Beata "]
names = [x.strip().title() for x in raw if x.strip()]
print(names)
# gdy dajesz title to srpawa że wszystko jest małe a pierwszy duży, ale każdy wyraz. capitalize zrobi ci pierwszy duży ale zdania
 

cities = ["  warszawa", "Kraków", "poznań ", "  ", "łódź"]
miasta = [f"Miasto: {x.strip().title()}" for x in cities if (len(x.strip()) > 5)]
print(miasta)
#f string to jest ważne a zapominam

data = [" Ala  ma kota ", "  ", "Pies i kot ", "KOT ", ""]
# old new_data = [x.lower().strip().capitalize().replace("  ", " ") for x in data if x.strip()]
new_data = [" ".join(x.split()).capitalize() + "." for x in data if x.strip()]
print(new_data)

# aha robisz + "coś" i ci dodaje coś xd
# Out:
# ['kot', 'pies', 'lew']
# ['Anna', 'Bartek', 'Adam', 'Beata']
# ['Miasto: Warszawa', 'Miasto: Kraków', 'Miasto: Poznań']
# ['Ala ma kota.', 'Pies i kot.', 'Kot.']

# %% [markdown]
# 58. zagnieżdżone pętle

# %%
A = [1, 2, 3]
B = [10, 20]

suma = [x + y for x in A for y in B]
print(suma)

A = ["Ala", "Bartek"]
B = ["pies", "kot"]

lista_zdań = [f"{x} ma {y}" for x in A for y in B]
print(lista_zdań)

nums = [1, 2, 3, 4]
letters = ["a", "b", "c"]

lista_krotek = [f"{y}→{x}" for x in nums for y in letters if x % 2 == 0 and y != "b"]
print(lista_krotek)
# pamiętaj, że =! tylko != to prawidłowe
# Out:
# [11, 21, 12, 22, 13, 23]
# ['Ala ma pies', 'Ala ma kot', 'Bartek ma pies', 'Bartek ma kot']
# ['a→2', 'c→2', 'a→4', 'c→4']

# %% [markdown]
# 59. Warunki wewnątrz wyrażeń (comprehensions)

# %%
lista = [-2, -1, 0, 1, 2]

dodatnie = [x for x in lista if x > 0]
print(dodatnie)
lista_napisów = ["minus" if x <= 0 else "plus" for x in lista]
print(lista_napisów)
# Out:
# [1, 2]
# ['minus', 'minus', 'minus', 'plus', 'plus']

# %% [markdown]
# 60. wydajność i czytelność

# %%
suma = sum(x*x for x in range(1,20) if x % 2 == 0)
# () zamiast []

squares = [x**2 for x in range(6)]
try:
    print(x)  # co się stanie?
except:
    NameError

# czemu tak? ponieważ x istnieje tylko w tej tworzonej liście, a nie poza nią
# w sumie tyle
